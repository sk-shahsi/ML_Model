# %% [markdown]
# <a href="https://colab.research.google.com/github/sk-shahsi/ML_Model/blob/master/classification_problem.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
df=pd.read_csv('/content/mushrooms.csv')

# %%
df
# Out:
#      class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0        p         x           s         n       t    p               f
# 1        e         x           s         y       t    a               f
# 2        e         b           s         w       t    l               f
# 3        p         x           y         w       t    p               f
# 4        e         x           s         g       f    n               f
# ...    ...       ...         ...       ...     ...  ...             ...
# 8119     e         k           s         n       f    n               a
# 8120     e         x           s         n       f    n               a
# 8121     e         f           s         n       f    n               a
# 8122     p         k           y         n       f    y               f
# 8123     e         x           s         n       f    n               a
#
#      gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# ...

# %%
df.dtypes
# Out:
# class                       object
# cap-shape                   object
# cap-surface                 object
# cap-color                   object
# bruises                     object
# odor                        object
# gill-attachment             object
# gill-spacing                object
# gill-size                   object
# gill-color                  object
# stalk-shape                 object
# stalk-root                  object
# stalk-surface-above-ring    object
# stalk-surface-below-ring    object
# stalk-color-above-ring      object
# stalk-color-below-ring      object
# veil-type                   object
# veil-color                  object
# ring-number                 object
# ring-type                   object
# spore-print-color           object
# population                  object
# habitat                     object
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [class, cap-shape, cap-surface, cap-color, bruises, odor, gill-attachment, gill-spacing, gill-size, gill-color, stalk-shape, stalk-root, stalk-surface-above-ring, stalk-surface-below-ring, stalk-color-above-ring, stalk-color-below-ring, veil-type, veil-color, ring-number, ring-type, spore-print-color, population, habitat]
# Index: []
#
# [0 rows x 23 columns]

# %%
df.isnull().sum()
# Out:
# class                       0
# cap-shape                   0
# cap-surface                 0
# cap-color                   0
# bruises                     0
# odor                        0
# gill-attachment             0
# gill-spacing                0
# gill-size                   0
# gill-color                  0
# stalk-shape                 0
# stalk-root                  0
# stalk-surface-above-ring    0
# stalk-surface-below-ring    0
# stalk-color-above-ring      0
# stalk-color-below-ring      0
# veil-type                   0
# veil-color                  0
# ring-number                 0
# ring-type                   0
# spore-print-color           0
# population                  0
# habitat                     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le=LabelEncoder()

# %%
for i in df.columns:
  if df[i].dtype =='object':
    df[i] = le.fit_transform(df[i])

# %%
df
# Out:
#       class  cap-shape  cap-surface  cap-color  bruises  odor  \
# 0         1          5            2          4        1     6
# 1         0          5            2          9        1     0
# 2         0          0            2          8        1     3
# 3         1          5            3          8        1     6
# 4         0          5            2          3        0     5
# ...     ...        ...          ...        ...      ...   ...
# 8119      0          3            2          4        0     5
# 8120      0          5            2          4        0     5
# 8121      0          2            2          4        0     5
# 8122      1          3            3          4        0     8
# 8123      0          5            2          4        0     5
#
#       gill-attachment  gill-spacing  gill-size  gill-color  ...  \
# 0                   1             0          1           4  ...
# 1                   1             0          0           4  ...
# ...

# %%
import matplotlib.pyplot as plt

# %%
for i in df.columns:
  if df[i].dtype !='object':
   plt.boxplot(df[i])
   plt.title(i)
   plt.show()

# %%
df.columns
# Out:
# Index(['class', 'cap-shape', 'cap-surface', 'cap-color', 'bruises', 'odor',
#        'gill-attachment', 'gill-spacing', 'gill-size', 'gill-color',
#        'stalk-shape', 'stalk-root', 'stalk-surface-above-ring',
#        'stalk-surface-below-ring', 'stalk-color-above-ring',
#        'stalk-color-below-ring', 'veil-type', 'veil-color', 'ring-number',
#        'ring-type', 'spore-print-color', 'population', 'habitat'],
#       dtype='object')

# %%
x=df.drop(columns='class')
y=df['class']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_train.shape
# Out:
# (6499, 22)

# %%
y_train.shape
# Out:
# (6499,)

# %%
x_test.shape
# Out:
# (1625, 22)

# %%
x_test.shape
# Out:
# (1625, 22)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logistic_model = LogisticRegression()

# %%
logistic_model.fit(x_train,y_train)
# Out:
# /usr/local/lib/python3.13/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
logistic_model.coef_
# Out:
# array([[-0.05544572,  0.42971847, -0.05277249, -0.86320128, -0.52235072,
#         -1.57693726, -6.56090588,  7.38922051, -0.11749989,  0.16765618,
#         -1.74929105, -4.42146675, -0.34112185, -0.13774254, -0.05263096,
#          0.        ,  5.85689616,  1.171362  ,  0.91286533, -0.2232285 ,
#         -0.39742834,  0.09788859]])

# %%
logistic_model.intercept_
# Out:
# array([0.53280923])

# %%
y_pred = logistic_model.predict(x_test)

# %%
y_pred
# Out:
# array([0, 1, 1, ..., 1, 1, 1])

# %%
probs = logistic_model.predict_proba(x_test)

# %%
probs
# Out:
# array([[9.99999702e-01, 2.98062856e-07],
#        [9.63770678e-02, 9.03622932e-01],
#        [5.46881567e-05, 9.99945312e-01],
#        ...,
#        [2.78555560e-05, 9.99972144e-01],
#        [4.54871752e-02, 9.54512825e-01],
#        [1.23989003e-01, 8.76010997e-01]])

# %%
from sklearn.metrics import *

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.947076923076923

# %%
confusion_matrix(y_pred,y_test)
# Out:
# array([[798,  41],
#        [ 45, 741]])

# %%
classification_report(y_pred,y_test)
# Out:
# '              precision    recall  f1-score   support\n\n           0       0.95      0.95      0.95       839\n           1       0.95      0.94      0.95       786\n\n    accuracy                           0.95      1625\n   macro avg       0.95      0.95      0.95      1625\nweighted avg       0.95      0.95      0.95      1625\n'

# %%
print(classification_report(y_pred,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      0.95      0.95       839
#            1       0.95      0.94      0.95       786
#
#     accuracy                           0.95      1625
#    macro avg       0.95      0.95      0.95      1625
# weighted avg       0.95      0.95      0.95      1625

# %%
from sklearn.metrics  import accuracy_score

# %%
#Linear model
from sklearn.linear_model import LinearRegression

# %%
linear_regression = LinearRegression()

# %%
linear_regression.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred_linear = linear_regression.predict(x_test)

# %%
y_pred_linear
# Out:
# array([-0.13364851,  0.81988077,  1.11233918, ...,  1.21742194,
#         0.929937  ,  0.87171213])

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error,r2_score

# %%
r2_score(y_test,y_pred_linear)
# Out:
# 0.729071844331977

# %%
mean_absolute_error(y_test,y_pred_linear)
# Out:
# 0.17002791429656744

# %%
mean_squared_error(y_test,y_pred_linear)
# Out:
# 0.06763659525620191

# %%
#Decision Tree
from sklearn.tree import DecisionTreeClassifier

# %%
model_Decision_Tree = DecisionTreeClassifier()

# %%
model_Decision_Tree.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_Desion_Tree =model_Decision_Tree.predict(x_test)

# %%
accuracy_score(y_pred_Desion_Tree,y_test)
# Out:
# 1.0

# %%
print(classification_report(y_pred_Desion_Tree,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       843
#            1       1.00      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
confusion_matrix(y_pred_Desion_Tree,y_test)
# Out:
# array([[843,   0],
#        [  0, 782]])

# %%
#Random Forest
from sklearn.ensemble import RandomForestClassifier

# %%
model_Random_forest = RandomForestClassifier()

# %%
model_Random_forest.fit(x_test,y_test)
# Out:
# RandomForestClassifier()

# %%
y_pred_Random_forest = model_Random_forest.predict(x_test)

# %%
accuracy_score(y_pred_Random_forest,y_test)
# Out:
# 1.0

# %%
print(classification_report(y_pred_Random_forest,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       843
#            1       1.00      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625

# %%
#XgBoost
from xgboost import XGBClassifier

# %%
model_xg = XGBClassifier()

# %%
model_xg.fit(x_train,y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=True, eval_metric=None, feature_types=None,
#               feature_weights=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=None,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=None,
#               n_jobs=None, num_parallel_tree=None, ...)

# %%
y_pred_XGB = model_xg.predict(x_test)

# %%
print(classification_report(y_pred_XGB,y_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00       843
#            1       1.00      1.00      1.00       782
#
#     accuracy                           1.00      1625
#    macro avg       1.00      1.00      1.00      1625
# weighted avg       1.00      1.00      1.00      1625
