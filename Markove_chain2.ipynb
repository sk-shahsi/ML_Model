# %% [markdown]
# <a href="https://colab.research.google.com/github/sk-shahsi/ML_Model/blob/master/Markove_chain2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/abcnews-date-text (1).csv")

# %%
df
# Out:
#          publish_date                                      headline_text
# 0            20030219  aba decides against community broadcasting lic...
# 1            20030219     act fire witnesses must be aware of defamation
# 2            20030219     a g calls for infrastructure protection summit
# 3            20030219           air nz staff in aust strike for pay rise
# 4            20030219      air nz strike to affect australian travellers
# ...               ...                                                ...
# 1244179      20211231  two aged care residents die as state records 2...
# 1244180      20211231  victoria records 5;919 new cases and seven deaths
# 1244181      20211231    wa delays adopting new close contact definition
# 1244182      20211231  western ringtail possums found badly dehydrate...
# 1244183      20211231  what makes you a close covid contact here are ...
#
# [1244184 rows x 2 columns]

# %%
df.isnull().sum().sum()
# Out:
# np.int64(0)

# %%
df.duplicated().sum()
# Out:
# np.int64(2)

# %%
! pip install Markovify

# %%
# Random Heading Generation using Markove Chain

# %%
import markovify

# %%
text_model= markovify.NewlineText(df.headline_text,state_size=2)

# %%
for i in range(10):
  print(text_model.make_sentence())
# Out:
# tokyo shootings prompt turf war queen elizabeth stakes
# tasmania facing a $1.9 million budget black hole psychiatrist
# former fbi acting drector andrew mccabe defends james sutherland
# hospital dealing with doctor
# sa hospitals still short of announcing comeback
# tollners power plan switch
# cattle weight dropping for se qld braces for more water for 12 new senators
# seasonal workers will boost interest in running for aust wine industry unfazed by pack of dogs in home invasion reports upset police
# man gets life for detainee
# police seek help over hervey bay teen looks to lure more western

# %%
text_model.make_sentence_with_start("airline")
# Out:
# 'airline to fly meningococcal vaccinations to begin in bali criticised'
